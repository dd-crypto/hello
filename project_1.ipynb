# %% [markdown]
# In this first part of Task 2, you should write a Python script for the ice cream ordering system. Your program must store the prices of the individual items (cones, scoop flavours and toppings). Specifically, the program should do the following:
# •	At the start, the program should ask for the customer’s name to personalise and track the order and then get the number of ice creams from the customer.
# •	For each ice cream, the cone type, scoop amount, scoop flavour, number and type of toppings should be taken from the customer.
# •	At the end the program should display the itemised order with the total price.
# •	The program should be able to handle invalid entries inputted (such as incorrect cone type, or invalid number of toppings)
#
#
#
#
#
#
#
# Additional Info:
# 1.	The maximum number of scoops per ice cream is 3
# 2.	The maximum number of toppings per ice cream is 4

# %%
f=open('ice_cream.txt','r')
for i in f:
    print(i)

str(input('Name :'))
x=str(input('Cone Type :'))
y=str(input('Scoops Flavours :'))
z=str(input('Toppings :'))
x=x.split()
a=' '.join(x)
if a.lower()=='plain cone':
    cone_price=1.5
    print('price of plain cone',cone_price)
elif a.lower()=='waffle cone':
    cone_price=2
    print('price of waffle cone',cone_price)
elif a.lower()=='cup':
    cone_price=1
    print('price of cup',cone_price)

y=y.split()
l1=[]
for i in y:
    l1.append(i)
l1=(len(l1))
if l1==3:
    scoop_price=5*3
    print('price of scoops :',scoop_price)
elif l1==2:
    scoop_price=5*2
    print('price of scoops :',scoop_price)
elif l1==1:
    scoop_price=5
    print('price of scoop :',scoop_price)
else:
    print('The maximum number of scoops per ice cream is 3')
z=z.split()
l2=[]
for i in z:
    l2.append(i)
a=len(l2)
if a<=4:
    l3=[]
    for i in l2:
        if i.lower()=='peanuts':
            p=0.75
            l3.append(p)
        elif i.lower()=='caramel-sauce':
            c=0.5
            l3.append(c)
        elif i.lower()=='rainbow-sprinkles':
            r=0.5
            l3.append(r)
        elif i.lower()=='pecan':
            pe=1
            l3.append(pe)
        elif i.lower()=='chocolate-sprinkles':
            ch=0.5
            l3.append(ch)
    toppings=sum(l3)
    print('price of toppings :',toppings)
else:
    print('The maximum number of toppings per ice cream is 4')


print('Total Bill :',cone_price+scoop_price+toppings)
# Out:
# catagory    Item                 Price
#
#
#
# Cone Type   Plain Cone            1.5
#
#             Waffle Cone            2
#
#             Cup                    1
#
#
#
# Scoop       Vanilla                5
#
# Flavours    Strawberry             5
#
#             Chocolate              5
#
#             Caramel                5
#
#             Mint                   5
#
#             Rainbow                5
#
#             Coffee                 5
#
#             Bubble gum             5
#
#
#
# Topping     Peanuts               0.75
#
# choices     Caramel Sauce         0.5
#
#             Rainbow Sprinkles     0.5
#
#             Pecan                  1
#
#             Chocolate Sprinkles   0.5
#
#
#
#
#
# Name :dhirendra
# Cone Type :plain cone
# Scoops Flavours :chocolate caramel
# Toppings :pecan
# price of plain cone 1.5
# price of scoops : 10
# price of toppings : 1
# Total Bill : 12.5
